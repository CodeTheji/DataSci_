# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
plt.style.use("ggplot")
# %matplotlib inline

# %%
data = pd.read_csv('corona_world.csv')
# Removing the sno column
data = data.drop(['Sno'], axis = 1)
# data['Country'].head(50)
# Out:
#                Date    Province/State               Country      Last Update  \
# 720  2/4/2020 22:00          Liaoning        Mainland China   4/2/2020 14:13
# 721  2/4/2020 22:00            Shanxi        Mainland China   4/2/2020 23:23
# 722  2/4/2020 22:00           Tianjin        Mainland China   4/2/2020 13:33
# 723  2/4/2020 22:00           Guizhou        Mainland China    5/2/2020 1:23
# 724  2/4/2020 22:00             Gansu        Mainland China   4/2/2020 15:43
# 725  2/4/2020 22:00             Jilin        Mainland China    5/2/2020 0:43
# 726  2/4/2020 22:00    Inner Mongolia        Mainland China    5/2/2020 1:53
# 727  2/4/2020 22:00           Ningxia        Mainland China    4/2/2020 2:13
# 728  2/4/2020 22:00          Xinjiang        Mainland China    5/2/2020 2:03
# 729  2/4/2020 22:00               NaN              Thailand   4/2/2020 15:33
# 730  2/4/2020 22:00               NaN             Singapore   4/2/2020 15:33
# ...

# %%
# converting to datetime
data['Date'] = pd.to_datetime(data['Date'])

# %% [markdown]
# ## COMBINING CHINA AND MAINLAND CHINA CASES

# %%
data = data.replace(to_replace = ['Mainland China'], value = ['China'])

data.tail(50)
# Out:
#                    Date    Province/State               Country  \
# 720 2020-02-04 22:00:00          Liaoning                 China
# 721 2020-02-04 22:00:00            Shanxi                 China
# 722 2020-02-04 22:00:00           Tianjin                 China
# 723 2020-02-04 22:00:00           Guizhou                 China
# 724 2020-02-04 22:00:00             Gansu                 China
# 725 2020-02-04 22:00:00             Jilin                 China
# 726 2020-02-04 22:00:00    Inner Mongolia                 China
# 727 2020-02-04 22:00:00           Ningxia                 China
# 728 2020-02-04 22:00:00          Xinjiang                 China
# 729 2020-02-04 22:00:00               NaN              Thailand
# 730 2020-02-04 22:00:00               NaN             Singapore
# 731 2020-02-04 22:00:00               NaN                 Japan
# 732 2020-02-04 22:00:00         Hong Kong             Hong Kong
# 733 2020-02-04 22:00:00           Qinghai                 China
# ...

# %% [markdown]
# - DATA SHOWS THERE ARE A TOTAL OF 770 DATA IN THE COLLECTION WITH DATE,COUNTRY, LAST UPDATE, CONFIRMED, DEATHS, RECOVERED AND PROVINCE/STATE BEING THE ONLY COLUMNS WITH MISSING OR NULL VALUES

# %% [markdown]
# ### CALCULATING THE TOTAL COUNTRIES AFFECTED AFTER THE COMBINATION

# %%
total_countries = data['Country'].unique().tolist()
no = len(total_countries)
no
# Out:
# 31

# %% [markdown]
# - After combining China and MainLand China, the total number of country affect is 31

# %%
data.describe()
# Out:
#           Confirmed      Deaths   Recovered
# count    770.000000  770.000000  770.000000
# mean     160.207792    3.436364    4.264935
# std     1015.504102   31.553727   28.718715
# min        0.000000    0.000000    0.000000
# 25%        2.000000    0.000000    0.000000
# 50%        8.000000    0.000000    0.000000
# 75%       58.750000    0.000000    1.000000
# max    16678.000000  479.000000  522.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 770 entries, 0 to 769
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            770 non-null    datetime64[ns]
#  1   Province/State  585 non-null    object
#  2   Country         770 non-null    object
#  3   Last Update     770 non-null    object
#  4   Confirmed       770 non-null    int64
#  5   Deaths          770 non-null    int64
#  6   Recovered       770 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 33.1+ KB

# %% [markdown]
# - AFTER SOME RESEARCHES THE INTERNET SHOWS THAT THERE WERE A TOTAL OF 2,817 DEATH COUNT AS AT 27/02/2020.WHLE THIS DATA SHOW JUST 770 TAKEN BETWEEN 22/01/2020 TO 04/02/2020. THIS DATASET MIGHT NOT BE VERY ACCURATE DUE TO INCOMPLETE DATA
#
# - ALSO ON AN AVERAGE 160 OUT OF 770 COUNTS HAS BEEN CONFIRMED WITH THE VIRUS

# %%
data.corr()
# Out:
#                 Sno  Confirmed    Deaths  Recovered
# Sno        1.000000   0.083996  0.052086   0.104204
# Confirmed  0.083996   1.000000  0.988916   0.986025
# Deaths     0.052086   0.988916  1.000000   0.963501
# Recovered  0.104204   0.986025  0.963501   1.000000

# %%
# Out:
#                    Date   Province/State Country      Last Update  Confirmed  \
# 0   2020-01-22 12:00:00            Anhui   China  1/22/2020 12:00          1
# 1   2020-01-22 12:00:00          Beijing   China  1/22/2020 12:00         14
# 2   2020-01-22 12:00:00        Chongqing   China  1/22/2020 12:00          6
# 3   2020-01-22 12:00:00           Fujian   China  1/22/2020 12:00          1
# 4   2020-01-22 12:00:00            Gansu   China  1/22/2020 12:00          0
# ..                  ...              ...     ...              ...        ...
# 765 2020-02-04 22:00:00       Boston, MA      US   1/2/2020 19:43          1
# 766 2020-02-04 22:00:00  Los Angeles, CA      US   1/2/2020 19:53          1
# 767 2020-02-04 22:00:00       Orange, CA      US   1/2/2020 19:53          1
# 768 2020-02-04 22:00:00      Seattle, WA      US   1/2/2020 19:43          1
# 769 2020-02-04 22:00:00        Tempe, AZ      US   1/2/2020 19:43          1
#
#      Deaths  Recovered
# ...

# %%
plt.scatter(x=df['Confirmed'], 
y=df['Confirmed'], 
s=df['Population']/1000, 
alpha=0.5, 
c=df['Bubble Color'])
