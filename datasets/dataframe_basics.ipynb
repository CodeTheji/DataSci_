# %% [markdown]
# Dataframe is most commonly used object in pandas. It is table like datastructure containing rows and columns similar to excel spreadsheet

# %%
import pandas as pd

# %%
weather_data = {
    "day": ["1/1/2017", "1/2/2017", "1/3/2017", "1/4/2017", "1/5/2017", "1/6/2017"],
    "temperature": [32,35,28,24,32,31],
    "windspeed": [6,7,2,7,4,2],
    "event": ["Rain", "Sunny", "Snow", "Snow", "Rain", "Sunny"]
}

df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.shape #rows, colums = df.shape
#print the above first to get the shape matrix

print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.day #To print the days
#print the above first to get the days
type(df.day) #its brings a series
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-ff6474b590e0> in <module>
# ----> 1 df.day #To print the days
#       2 #print the above first to get the days
#       3 type(df.day) #its brings a series
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'day'

# %%
df2 = pd.read_csv("countries.csv")
df2
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
import pandas as pd
df = pd.read_csv('nyc_weather.csv')
df_copy = df.copy() #I duplicated this because i want to alter the NA value on a seperate file

# %%
import pandas as pd
data = pd.read_csv('countries.csv')

# %%
mask_1952 = data.year == 1952
data[mask_1952]
# Out:
#                  country  year  population
# 0            Afghanistan  1952     8425333
# 12               Albania  1952     1282697
# 24               Algeria  1952     9279525
# 36                Angola  1952     4232095
# 48             Argentina  1952    17876956
# ...                  ...   ...         ...
# 1644             Vietnam  1952    26246839
# 1656  West Bank and Gaza  1952     1030585
# 1668         Yemen, Rep.  1952     4963829
# 1680              Zambia  1952     2672000
# 1692            Zimbabwe  1952     3080907
#
# [142 rows x 3 columns]

# %%
data[mask_1952].country
# Out:
# 0              Afghanistan
# 12                 Albania
# 24                 Algeria
# 36                  Angola
# 48               Argentina
#                ...
# 1644               Vietnam
# 1656    West Bank and Gaza
# 1668           Yemen, Rep.
# 1680                Zambia
# 1692              Zimbabwe
# Name: country, Length: 142, dtype: object

# %%
mask_Nigeria = data.country == 'Nigeria'
data[mask_Nigeria]
# Out:
#       country  year  population
# 1128  Nigeria  1952    33119096
# 1129  Nigeria  1957    37173340
# 1130  Nigeria  1962    41871351
# 1131  Nigeria  1967    47287752
# 1132  Nigeria  1972    53740085
# 1133  Nigeria  1977    62209173
# 1134  Nigeria  1982    73039376
# 1135  Nigeria  1987    81551520
# 1136  Nigeria  1992    93364244
# 1137  Nigeria  1997   106207839
# 1138  Nigeria  2002   119901274
# 1139  Nigeria  2007   135031164

# %%
#To populate two countries of an exact year
mask_country = (data.country == 'Nigeria') | (data.country == 'China') #multiple constaint (| --> or) and (& --> and)
niger_china = data[mask_country]
only_1952 = niger_china[niger_china.year == 1952]
only_1952
# Out:
#       country  year  population
# 288     China  1952   556263527
# 1128  Nigeria  1952    33119096

# %%
print(df)
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
df.Humidity #or df["Humidity"]
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
#to get the temperature when it is minimal
df["Temperature"].min()
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df["Temperature"].min()
# Out:
# 20

# %%
#to get the day when the windspeedmph is low
df["WindSpeedMPH"][df["Temperature"] == df["Temperature"].min()]
# Out:
# 4    5.0
# Name: WindSpeedMPH, dtype: float64

# %%
#to check the day when it rained that is... event = rain
df["EST"][df["Events"] == "Rain"]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
#to replace those NA part of a specific column
df_copy["WindSpeedMPH"].fillna(9999, inplace = True) # FILL NAN values using zero or 
# df_copy["WindSpeedMPH"].fillna(df["WindSpeedMPH"].mean() inplace = True) #fill NAN values with mean
df_copy
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
#to add new column with data to the table
new_col = pd.Series([i for i in range(31)])
df["new_col"] = new_col
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
#to check the technical overview of the whole data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 12 columns):
# EST                     31 non-null object
# Temperature             31 non-null int64
# DewPoint                31 non-null int64
# Humidity                31 non-null int64
# Sea Level PressureIn    31 non-null float64
# VisibilityMiles         31 non-null int64
# WindSpeedMPH            28 non-null float64
# PrecipitationIn         31 non-null object
# CloudCover              31 non-null int64
# Events                  9 non-null object
# WindDirDegrees          31 non-null int64
# new_col                 31 non-null int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 3.0+ KB

# %%
#to get all the mathematic sets that comes with it
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees    new_col
# count        31.000000     28.000000   31.000000       31.000000  31.000000
# mean          9.193548      6.892857    3.129032      247.129032  15.000000
# std           1.939405      2.871821    2.629853       92.308086   9.092121
# min           1.000000      2.000000    0.000000       34.000000   0.000000
# ...

# %%
# to get the non numeric values
df.describe(include = "O")
# this shows those values that are not numeric that is the object...for eg the event; the total values is 31,  9 has the values..while the rest are object
# Out:
#               EST PrecipitationIn Events
# count          31              31      9
# unique         31               7      3
# top     1/16/2016               0   Rain
# freq            1              19      4

# %%
#to check the correlation
df.corr()
# Out:
#                       Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Temperature              1.000000  0.883286  0.445091             -0.376514
# DewPoint                 0.883286  1.000000  0.780407             -0.524376
# Humidity                 0.445091  0.780407  1.000000             -0.506997
# Sea Level PressureIn    -0.376514 -0.524376 -0.506997              1.000000
# VisibilityMiles         -0.060891 -0.365590 -0.660445              0.426908
# WindSpeedMPH            -0.396870 -0.075505  0.324650             -0.433892
# CloudCover               0.314066  0.587759  0.740046             -0.362859
# WindDirDegrees          -0.216813 -0.409942 -0.497563              0.030167
# new_col                  0.029274  0.082483  0.108715             -0.269357
#
#                       VisibilityMiles  WindSpeedMPH  CloudCover  \
# Temperature                 -0.060891     -0.396870    0.314066
# DewPoint                    -0.365590     -0.075505    0.587759
# ...
