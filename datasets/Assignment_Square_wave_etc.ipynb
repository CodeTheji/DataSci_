# %%
from scipy import signal
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random

# %%
# Sampling rate 500 hz / second
t = np.linspace(0, 0.5, 500, endpoint=True)

# Plot the square wave signal
plt.plot(t, signal.square(2 * np.pi * 5 * t))

# Give a title for the square wave plot
plt.title('Sqaure wave - 5 Hz sampled at 500 Hz /second')

# Give x axis label for the square wave plot
plt.xlabel('X Time')
plt.ylabel('Y Amplitude')
# Out:
# Text(0, 0.5, 'Y Amplitude')

# %%
# Sampling rate 500 hz / second
t = np.linspace(0, 0.5, 500, endpoint=True)

# Plot the square wave signal
plt.plot(t, signal.square(2 * np.pi * 5 * t))

# Give a title for the square wave plot
plt.title('Sqaure wave - 5 Hz sampled at 500 Hz /second')

# Give x axis label for the square wave plot
plt.xlabel('X Time')
plt.ylabel('Y Amplitude')

plt.grid(True, which='both')

#To line out the origin/middle
plt.axhline(y=0, color='k')

# Set the max and min values for y axis
plt.ylim(-2, 2)
plt.show()

# %%
# z = [random.randint(60,70) for _ in range(7)]
# # x = [random.randint(0, 1) for _ in range(7)]
# y = [random.randint(0, 1) for _ in range(7)]
# y = [0,1,0,1,0,1,0]
# x = sin(2*pi*y)
# z = [1,2,2,4,3,2,3]

x = [1,3,5,7,9]
y = [4,4,4,4,4]

# %% [markdown]
# To work on the Sine Wave

# %% [markdown]
# Saw tooth wave

# %%
# Give a title for the square wave plot
plt.title('Saw tooth wave - 5 Hz sampled at 500 Hz /second')

# Give x axis label for the square wave plot
plt.xlabel('X Time')
plt.ylabel('Y Amplitude')

plt.plot(t, signal.sawtooth(2 * np.pi * 5 * t))
plt.show()
