# %%
import requests
import datetime
from dateutil.parser import parse

# %%
days = 10
response = requests.get(f'http://checklight.pythonanywhere.com/get_readings/1x0d001/{days}/')

# %%
print(response.json())
# Out:
# {'response': 'success', 'streets': [{'device': 5, 'name': 220.0, 'id': 157303, 'status': 1, 'time': 'Jan. 24, 2020, 01:04 AM.'}, {'device': 5, 'name': 220.0, 'id': 157304, 'status': 1, 'time': 'Jan. 24, 2020, 01:05 AM.'}, {'device': 5, 'name': 220.0, 'id': 157305, 'status': 1, 'time': 'Jan. 24, 2020, 01:06 AM.'}, {'device': 5, 'name': 220.0, 'id': 157306, 'status': 1, 'time': 'Jan. 24, 2020, 01:07 AM.'}, {'device': 5, 'name': 220.0, 'id': 157307, 'status': 1, 'time': 'Jan. 24, 2020, 01:07 AM.'}, {'device': 5, 'name': 220.0, 'id': 157308, 'status': 1, 'time': 'Jan. 24, 2020, 01:08 AM.'}, {'device': 5, 'name': 220.0, 'id': 157309, 'status': 1, 'time': 'Jan. 24, 2020, 01:09 AM.'}, {'device': 5, 'name': 220.0, 'id': 157310, 'status': 1, 'time': 'Jan. 24, 2020, 01:09 AM.'}, {'device': 5, 'name': 220.0, 'id': 157311, 'status': 1, 'time': 'Jan. 24, 2020, 01:10 AM.'}, {'device': 5, 'name': 220.0, 'id': 157312, 'status': 1, 'time': 'Jan. 24, 2020, 01:11 AM.'}, {'device': 5, 'name': 220.0, 'id': 157313, 'status': 1, 'time': 'Jan. 24, 2020, 01:12 AM.'}, {'device': 5, 'name': 220.0, 'id': 157314, 'status': 1, 'time': 'Jan. 24, 2020, 01:12 AM.'}, {'device': 5, 'name': 220.0, 'id': 157315, 'status': 1, 'time': 'Jan. 24, 2020, 01:13 AM.'}, {'device': 5, 'name': 220.0, 'id': 157316, 'status': 1, 'time': 'Jan. 24, 2020, 01:14 AM.'}, {'device': 5, 'name': 220.0, 'id': 157317, 'status': 1, 'time': 'Jan. 24, 2020, 01:15 AM.'}, {'device': 5, 'name': 220.0, 'id': 157318, 'status': 1, 'time': 'Jan. 24, 2020, 01:15 AM.'}, {'device': 5, 'name': 220.0, 'id': 157319, 'status': 1, 'time': 'Jan. 24, 2020, 01:16 AM.'}, {'device': 5, 'name': 220.0, 'id': 157320, 'status': 1, 'time': 'Jan. 24, 2020, 01:17 AM.'}, {'device': 5, 'name': 220.0, 'id': 157321, 'status': 1, 'time': 'Jan. 24, 2020, 01:17 AM.'}, {'device': 5, 'name': 220.0, 'id': 157322, 'status': 1, 'time': 'Jan. 24, 2020, 01:18 AM.'}, {'device': 5, 'name': 220.0, 'id': 157323, 'status': 1, 'time': 'Jan. 24, 2020, 01:19 AM.'}, {'device': 5, 'name': 220.0, 'id': 157324, 'status': 1, 'time': 'Jan. 24, 2020, 01:20 AM.'}, {'device': 5, 'name': 220.0, 'id': 157325, 'status': 1, 'time': 'Jan. 24, 2020, 01:20 AM.'}, {'device': 5, 'name': 220.0, 'id': 157326, 'status': 1, 'time': 'Jan. 24, 2020, 01:21 AM.'}, {'device': 5, 'name': 220.0, 'id': 157328, 'status': 1, 'time': 'Jan. 24, 2020, 01:22 AM.'}, {'device': 5, 'name': 220.0, 'id': 157330, 'status': 1, 'time': 'Jan. 24, 2020, 01:22 AM.'}, {'device': 5, 'name': 220.0, 'id': 157332, 'status': 1, 'time': 'Jan. 24, 2020, 01:23 AM.'}, {'device': 5, 'name': 220.0, 'id': 157334, 'status': 1, 'time': 'Jan. 24, 2020, 01:24 AM.'}, {'device': 5, 'name': 220.0, 'id': 157336, 'status': 1, 'time': 'Jan. 24, 2020, 01:25 AM.'}, {'device': 5, 'name': 220.0, 'id': 157338, 'status': 1, 'time': 'Jan. 24, 2020, 01:25 AM.'}, {'device': 5, 'name': 220.0, 'id': 157340, 'status': 1, 'time': 'Jan. 24, 2020, 01:26 AM.'}, {'device': 5, 'name': 220.0, 'id': 157342, 'status': 1, 'time': 'Jan. 24, 2020, 01:27 AM.'}, {'device': 5, 'name': 220.0, 'id': 157345, 'status': 1, 'time': 'Jan. 24, 2020, 01:28 AM.'}, {'device': 5, 'name': 220.0, 'id': 157347, 'status': 1, 'time': 'Jan. 24, 2020, 01:28 AM.'}, {'device': 5, 'name': 220.0, 'id': 157349, 'status': 1, 'time': 'Jan. 24, 2020, 01:29 AM.'}, {'device': 5, 'name': 220.0, 'id': 157351, 'status': 1, 'time': 'Jan. 24, 2020, 01:30 AM.'}, {'device': 5, 'name': 220.0, 'id': 157353, 'status': 1, 'time': 'Jan. 24, 2020, 01:30 AM.'}, {'device': 5, 'name': 220.0, 'id': 157355, 'status': 1, 'time': 'Jan. 24, 2020, 01:31 AM.'}, {'device': 5, 'name': 220.0, 'id': 157357, 'status': 1, 'time': 'Jan. 24, 2020, 01:32 AM.'}, {'device': 5, 'name': 220.0, 'id': 157359, 'status': 1, 'time': 'Jan. 24, 2020, 01:33 AM.'}, {'device': 5, 'name': 220.0, 'id': 157360, 'status': 1, 'time': 'Jan. 24, 2020, 01:33 AM.'}, {'device': 5, 'name': 220.0, 'id': 157363, 'status': 1, 'time': 'Jan. 24, 2020, 01:34 AM.'}, {'device': 5, 'name': 220.0, 'id': 157364, 'status': 1, 't ...

# %%
#### GET RAW DATA IN JSON FORMAT

raw_data = response.json()

# %%
start_date = parse(input("Enter start date in format(YYYY-MM-DD) : "))
end_date = parse(input("Enter end date in format(YYYY-MM-DD) : "))

for data in raw_data.get("streets"):
    #data = parse(data.get("time"))
    date = datetime.datetime.strptime(data.get("time"), "%b. %d, %Y, %I:%M %p.")
    if start_date <= date and end_date >= date:
        print(date)
# Out:
# Enter start date in format(YYYY-MM-DD) :
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-fff58c6a7ebb> in <module>
# ----> 1 start_date = parse(input("Enter start date in format(YYYY-MM-DD) : "))
#       2 end_date = parse(input("Enter end date in format(YYYY-MM-DD) : "))
#       3
#       4 for data in raw_data.get("streets"):
#       5     #data = parse(data.get("time"))
#
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1356         return parser(parserinfo).parse(timestr, **kwargs)
#    1357     else:
# -> 1358         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1359
#    1360
#
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650
#     651         if len(res) == 0:
# --> 652             raise ValueError("String does not contain a date:", timestr)
#     653
#     654         ret = self._build_naive(res, default)
#
# ValueError: ('String does not contain a date:', '')

# %%
yesterday_str = "2020-02-02"
today_str = "2020-02-03"

# %%
yesterday_obj = datetime.datetime,strptime(yesterday_str, "%Y-%m-%d")
today_obj = datetime.datetime.strptime(today_str, "%Y-%m-%d")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-2eb04c01d8d4> in <module>
# ----> 1 yesterday_obj = datetime.datetime,strptime(yesterday_str, "%Y-%m-%d")
#       2 today_obj = datetime.datetime.strptime(today_str, "%Y-%m-%d")
#
# NameError: name 'strptime' is not defined

# %%
yesterday_obj == today_obj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1444f67573d7> in <module>
# ----> 1 yesterday_obj == today_obj
#
# NameError: name 'yesterday_obj' is not defined

# %%
yesterday == yesterday_obj
